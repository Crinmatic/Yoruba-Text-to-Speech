# %% [markdown]
# <a href="https://colab.research.google.com/github/Crinmatic/Yoruba-Text-to-Speech/blob/main/SR_Test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install tensorflow==1.15

# %%
# !cd /content/drive/MyDrive/Speech_rec_2

# %%
#@title Download Tacotron 2

import os
#!git clone -q https://github.com/NVIDIA/flowtron.git
#!cp -r flowtron /content/drive/MyDrive/Speech_rec_2
os.chdir('/content/drive/MyDrive/Speech_rec_2/flowtron/')
# !git submodule update --init; cd tacotron2; git submodule update --init
#!pip install -q unidecode tensorboardX

# %%
# !pip install -r requirements.txt

# %%
# %pip install unidecode
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 235 kB 36.4 MB/s
# ...

# %%
# !python train.py -c config.json -p train_config.ignore_layers=["speaker_embedding.weight"] train_config.checkpoint_path="models/flowtron_ljs.pt"
# Out:
# train_config.ignore_layers=[speaker_embedding.weight]
# train_config.ignore_layers:[speaker_embedding.weight] was not parsed
# ignore_layers=[speaker_embedding.weight]
# ignore_layers:[speaker_embedding.weight] was not parsed
# train_config.checkpoint_path=models/flowtron_ljs.pt
# train_config.checkpoint_path:models/flowtron_ljs.pt was not parsed
# checkpoint_path=models/flowtron_ljs.pt
# checkpoint_path:models/flowtron_ljs.pt was not parsed
# ...

# %%
# !python train.py -c config.json -p train_config.output_directory=outdir data_config.use_attn_prior=1

# %%
# !python inference.py -c config.json -f models/flowtron_ljs.pt -w models/waveglow_256channels_ljs_v2.pt -t "Akitiyan àwọn ajíhìnrere tí wọ́n ṣe àkọsílẹ̀ àkọtọ́ èdè Yòrùbá kò ṣe é fọwọ́ rọ́ sẹ́yìn." -i 0
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/serialization.py:786: SourceChangeWarning: source code of class 'torch.nn.modules.conv.ConvTranspose1d' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)
# /usr/local/lib/python3.7/dist-packages/torch/serialization.py:786: SourceChangeWarning: source code of class 'torch.nn.modules.container.ModuleList' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)
# ...

# %%
231
